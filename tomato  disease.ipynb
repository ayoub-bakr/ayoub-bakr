# %% [markdown]
# <a href="https://colab.research.google.com/github/ayoub-bakr/ayoub-bakr/blob/main/tomato%20%20disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/arjuntejaswi/plant-village/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ayoubbakr
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/arjuntejaswi/plant-village
# ...
# 100%|██████████| 329M/329M [00:11<00:00, 29.3MB/s]

# %%
import shutil
import os

base_path = "/content/plant-village/PlantVillage"

for folder in os.listdir(base_path):
    if "potato" in folder:
        folder_path = os.path.join(base_path, folder)
        shutil.rmtree(folder_path)

# %%
base_path = "/content/plant-village/PlantVillage"

for folder in os.listdir(base_path):
    if "Pepper__bell" in folder:
        folder_path = os.path.join(base_path, folder)
        shutil.rmtree(folder_path)

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/plant-village/PlantVillage",
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 16011 files belonging to 10 classes.

# %%
CLASS_NAMES = dataset.class_names
CLASS_NAMES
# Out:
# ['Tomato_Bacterial_spot',
#  'Tomato_Early_blight',
#  'Tomato_Late_blight',
#  'Tomato_Leaf_Mold',
#  'Tomato_Septoria_leaf_spot',
#  'Tomato_Spider_mites_Two_spotted_spider_mite',
#  'Tomato__Target_Spot',
#  'Tomato__Tomato_YellowLeaf__Curl_Virus',
#  'Tomato__Tomato_mosaic_virus',
#  'Tomato_healthy']

# %%
len(dataset)
# Out:
# 501

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/plant-village"

drive_path = "/content/drive/My Drive/plant-village"


shutil.copytree(dataset_path, drive_path)
# Out:
# '/content/drive/My Drive/plant-village'
